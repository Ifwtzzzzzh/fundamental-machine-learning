# %% [markdown]
# ### Import Library
# Di sini, kita akan mengimport berbagai macam library yang kita gunakan untuk melakukan analisis menggunakan algoritma Q Learngin. Algoritma yang digunakan, seperti pandas, numpy, pylab, dan numpy. Semua library tersebut, kita gunakan untuk melakukan proses pengolahan, analisis, dan visualisasi data.

# %%
import pandas as pd
import numpy as np
import pylab as plt
import numpy as np

# %% [markdown]
# ### Membaca Dataset
# Di sini, kita akan membaca dataset dari file player_statistics_cleaned_final.csv. Kita simpan dataset ke dalam data frame atau di sini kita masukan ke dalam variable df.

# %%
df = pd.read_csv("player_statistics_cleaned_final.csv")
df
# Out:
#                TeamName PlayerName Position  Games  Win rate  KDA  Avg kills  \
# 0           Top Esports        369      Top      8     0.500  3.1        2.5
# 1             Dplus KIA     aiming      Adc      9     0.333  4.8        5.0
# 2         MAD Lions KOI     alvaro  Support      5     0.200  1.5        0.2
# 3           Team Liquid        apa      Mid     10     0.500  2.4        3.5
# 4             PSG Talon       azhi      Top      5     0.200  2.3        2.2
# ..                  ...        ...      ...    ...       ...  ...        ...
# 76          Team Liquid       yeon      Adc     10     0.500  4.9        3.8
# 77           G2 Esports       yike   Jungle      8     0.375  4.5        3.1
# 78  Hanwha Life Esports       zeka      Mid     12     0.500  3.6        3.8
# 79                   T1       zeus      Top      8     0.875  7.1        3.9
# 80          LNG Esports       zika      Top      8     0.625  3.8        4.6
#
#     Avg deaths  Avg assists  CSPerMin  ...  Avg VWPM  GD@15  CSD@15  XPD@15  \
# 0          2.4          4.9       7.6  ...      0.13    322       5     424
# 1          2.0          4.7      10.1  ...      0.10   -112       1      97
# 2          4.4          6.2       1.2  ...      0.49     -3       2    -256
# 3          3.2          4.2       8.7  ...      0.18    278       2     216
# 4          3.0          4.8       7.5  ...      0.18   -311     -10    -168
# ..         ...          ...       ...  ...       ...    ...     ...     ...
# 76         1.8          5.0      10.0  ...      0.16    224       6     571
# 77         2.4          7.6       6.4  ...      0.22    102       4     -80
# 78         2.8          6.2       9.1  ...      0.24    288       2      66
# 79         1.6          7.6       7.9  ...      0.19    633       8     370
# 80         3.1          7.1       8.2  ...      0.19    321      -2     -95
#
#      FB %  FB Victim  Penta Kills  Solo Kills        Country  FlashKeybind
# 0   0.000      0.250            0           2          China             D
# 1   0.333      0.000            0           2    South Korea             F
# 2   0.000      0.600            0           -          Spain             D
# 3   0.400      0.000            0           3  United States             D
# 4   0.200      0.000            0           -         Taiwan             D
# ..    ...        ...          ...         ...            ...           ...
# 76  0.500      0.000            0           -  United States             D
# 77  0.250      0.000            0           2         Sweden             D
# 78  0.250      0.167            0           1    South Korea             F
# 79  0.125      0.000            0           2    South Korea             F
# 80  0.375      0.125            0           2          China             D
#
# [81 rows x 27 columns]

# %% [markdown]
# ### Menampilkan Performa Player dari Masing-Masing Team
# Di sini, kita akan melakukan sorting performa player dari masing-masing team. Setiap team memiliki performa yang berbeda-beda. Hal tersebut kita lakukan dengan tujuan untuk menganalisis masing-masing team secara terpisah.

# %%
team_groups = df.groupby('TeamName')
for team, data in team_groups:
    print(f"\nTeam: {team}")
    print(data[['PlayerName', 'Position', 'Games', 'Win rate', 'KDA']])
# Out:
# Team: Bilibili Gaming
#    PlayerName Position  Games  Win rate  KDA
# 6         bin      Top     12     0.667  4.2
# 23        elk      Adc     12     0.667  4.4
# 42     knight      Mid     12     0.667  5.0
# 55         on  Support     12     0.667  2.7
# 70        wei   Jungle      3     0.333  3.1
# 75        xun   Jungle      9     0.778  5.3
#
# Team: Dplus KIA
#    PlayerName Position  Games  Win rate  KDA
# 1      aiming      Adc      9     0.333  4.8
# 41     kingen      Top      9     0.333  1.8
# 47      lucid   Jungle      9     0.333  1.7
# 52      moham  Support      9     0.333  1.9
# 63  showmaker      Mid      9     0.333  3.1
#
# Team: FlyQuest
#    PlayerName Position  Games  Win rate  KDA
# 9       busio  Support     14       0.5  3.7
# 10      bwipo      Top     14       0.5  1.7
# 34   inspired   Jungle     14       0.5  4.7
# 49      massu      Adc     14       0.5  4.4
# 60       quad      Mid     14       0.5  5.2
#
# Team: Fnatic
#    PlayerName Position  Games  Win rate  KDA
# 32   humanoid      Mid      6     0.333  2.2
# 36        jun  Support      6     0.333  2.9
# 54       noah      Adc      6     0.333  5.9
# 57  oscarinin      Top      6     0.333  2.0
# 61     razork   Jungle      6     0.333  3.1
#
# Team: G2 Esports
#      PlayerName Position  Games  Win rate  KDA
# 8   brokenblade      Top      8     0.375  3.7
# 12         caps      Mid      8     0.375  3.6
# 31    hans sama      Adc      8     0.375  3.1
# 51        mikyx  Support      8     0.375  1.8
# 77         yike   Jungle      8     0.375  4.5
#
# Team: GAM Esports
#    PlayerName Position  Games  Win rate  KDA
# 21   easylove      Adc      8     0.375  3.4
# 22       elio  Support      8     0.375  2.8
# 25        emo      Mid      8     0.375  3.2
# 39      kiaya      Top      8     0.375  3.3
# 45       levi   Jungle      8     0.375  2.3
#
# Team: Gen.G
#    PlayerName Position  Games  Win rate  KDA
# 11     canyon   Jungle     10       0.7  6.5
# 14      chovy      Mid     10       0.7  7.8
# 40       kiin      Top     10       0.7  3.8
# 44    lehends  Support     10       0.7  3.2
# 59       peyz      Adc     10       0.7  8.4
#
# Team: Hanwha Life Esports
#    PlayerName Position  Games  Win rate  KDA
# 18    delight  Support     12       0.5  3.2
# 19      doran      Top     12       0.5  2.9
# 58     peanut   Jungle     12       0.5  3.6
# 69      viper      Adc     12       0.5  4.2
# 78       zeka      Mid     12       0.5  3.6
#
# Team: LNG Esports
#    PlayerName Position  Games  Win rate  KDA
# 28       gala      Adc      8     0.625  7.2
# 30       hang  Support      8     0.625  2.9
# 62      scout      Mid      8     0.625  9.3
# 71     weiwei   Jungle      8     0.625  3.9
# 80       zika      Top      8     0.625  3.8
#
# Team: MAD Lions KOI
#    PlayerName Position  Games  Win rate  KDA
# 2      alvaro  Support      5       0.2  1.5
# 24     elyoya   Jungle      5       0.2  1.8
# 27  fresskowy      Mid      5       0.2  1.3
# 53      myrwn      Top      5       0.2  1.2
# 64       supa      Adc      5       0.2  1.6
#
# Team: PSG Talon
#    PlayerName Position  Games  Win rate  KDA
# 4        azhi      Top      5       0.2  2.3
# 5       betty      Adc      5       0.2  4.4
# 37     junjia   Jungle      5       0.2  2.7
# 48      maple      Mid      5       0.2  2.2
# 73      woody  Support      5       0.2  3.3
#
# Team: PaiN Gaming
#    PlayerName Position  Games  Win rate  KDA
# 13     cariok   Jungle      4       0.0  1.5
# 20   dynquedo      Mid      4       0.0  2.4
# 43       kuri  Support      4       0.0  2.0
# 67      titan      Adc      4       0.0  1.8
# 72      wizer      Top      4       0.0  1.6
#
# Team: T1
#    PlayerName Position  Games  Win rate  KDA
# 26      faker      Mid      8     0.875  4.8
# 29   gumayusi      Adc      8     0.875  9.1
# 38      keria  Support      8     0.875  7.5
# 56       oner   Jungle      8     0.875  6.8
# 79       zeus      Top      8     0.875  7.1
#
# Team: Team Liquid
#    PlayerName Position  Games  Win rate  KDA
# 3         apa      Mid     10       0.5  2.4
# 15     corejj  Support     10       0.5  3.6
# 33     impact      Top     10       0.5  2.5
# 68       umti   Jungle     10       0.5  3.8
# 76       yeon      Adc     10       0.5  4.9
#
# Team: Top Esports
#     PlayerName Position  Games  Win rate  KDA
# 0          369      Top      8       0.5  3.1
# 16       creme      Mid      8       0.5  3.6
# 35  jackeylove      Adc      8       0.5  3.4
# 50       meiko  Support      8       0.5  3.1
# 66        tian   Jungle      8       0.5  4.4
#
# Team: Weibo Gaming
#    PlayerName Position  Games  Win rate  KDA
# 7     breathe      Top     13     0.615  4.1
# 17      crisp  Support     13     0.615  3.7
# 46      light      Adc     13     0.615  6.0
# 65     tarzan   Jungle     13     0.615  3.5
# 74     xiaohu      Mid     13     0.615  6.2

# %% [markdown]
# ### Menghitung Rata-Rata Win Rate dan KDA
# Di sini, kita akan melakukan penghitungan Win Rate dan KDA dari masing-masing team. Di dalamnya terdapat rata-rata Games, Win rate, dan KDA. Lalu, kita akan melakukan function aggregasi. Di mana kita akan menghitung rata-rata pada setiap kolom. Kita ubah kolom PlayerName menjadi list. Hal tersebut bertujuan untuk memudahkan kita melihat semua player yang berada dalam team yang sama.

# %%
team_groups_summary = df.groupby('TeamName').agg({
    'PlayerName': list,
    'Games': 'mean',
    'Win rate': 'mean',
    'KDA': 'mean'
}).reset_index()

team_groups_summary.columns = ['TeamName', 'PlayerList', 'Games', 'Win rate', 'Avg_KDA']
team_groups_summary
# Out:
#                TeamName                                   PlayerList  Games  \
# 0       Bilibili Gaming             [bin, elk, knight, on, wei, xun]   10.0
# 1             Dplus KIA    [aiming, kingen, lucid, moham, showmaker]    9.0
# 2              FlyQuest        [busio, bwipo, inspired, massu, quad]   14.0
# 3                Fnatic     [humanoid, jun, noah, oscarinin, razork]    6.0
# 4            G2 Esports  [brokenblade, caps, hans sama, mikyx, yike]    8.0
# 5           GAM Esports           [easylove, elio, emo, kiaya, levi]    8.0
# 6                 Gen.G         [canyon, chovy, kiin, lehends, peyz]   10.0
# 7   Hanwha Life Esports        [delight, doran, peanut, viper, zeka]   12.0
# 8           LNG Esports            [gala, hang, scout, weiwei, zika]    8.0
# 9         MAD Lions KOI     [alvaro, elyoya, fresskowy, myrwn, supa]    5.0
# 10            PSG Talon          [azhi, betty, junjia, maple, woody]    5.0
# 11          PaiN Gaming       [cariok, dynquedo, kuri, titan, wizer]    4.0
# 12                   T1         [faker, gumayusi, keria, oner, zeus]    8.0
# 13          Team Liquid            [apa, corejj, impact, umti, yeon]   10.0
# 14          Top Esports        [369, creme, jackeylove, meiko, tian]    8.0
# 15         Weibo Gaming      [breathe, crisp, light, tarzan, xiaohu]   13.0
#
#     Win rate   Avg_KDA
# 0   0.629833  4.116667
# 1   0.333000  2.660000
# 2   0.500000  3.940000
# 3   0.333000  3.220000
# 4   0.375000  3.340000
# 5   0.375000  3.000000
# 6   0.700000  5.940000
# 7   0.500000  3.500000
# 8   0.625000  5.420000
# 9   0.200000  1.480000
# 10  0.200000  2.980000
# 11  0.000000  1.860000
# 12  0.875000  7.060000
# 13  0.500000  3.440000
# 14  0.500000  3.520000
# 15  0.615000  4.700000

# %% [markdown]
# ### Parameter Q Learning
# Di sini, kita akan menambahkan parameter pada Q Learning. Alpha kita gunakan untuk mencari seberapa banyak nilai Q pada setiap literasi yang kita lakukan. Gamma kita gunakan untuk mencari seberapa penting reward ke depannya. Epsilon kita gunakan untuk mencari seberapa sering agen akan mengambil aksi secara random dibandingkankan mengambil aksi berdasarkan value Q yang telah kita latih. Episodes kita gunakan untuk mencari total iterasi pelatihan yang mungkin untuk dilakukan.

# %%
alpha = 0.1
gamma = 0.9
epsilon = 0.2
episodes = 100

# %% [markdown]
# ### Function Pilih Aksi dan Hitung Reward
# Di sini, kita akan function choose_action dan calculate_reward. Function choose_action kita gunakan untuk menetukan pilihan yang akan kita ambil yang mengacu pada nilai epsilon dan table Q. Function calculate_reward kita gunakan untuk melakukan proses penghitungan reward yang akan diberikan yang mengacu pada pilihan yang dipilih dan performa team.

# %%
def choose_action(state, epsilon, Q_table):
    if np.random.uniform(0, 1) < epsilon:
        return np.random.choice(2)
    else:
        return np.argmax(Q_table[state[0], state[1]])

def calculate_reward(action, team_stats):
    if action == 0:
        return team_stats['Win rate'] * 0.5
    elif action == 1:
        return team_stats['Avg_KDA'] * 0.5

# %% [markdown]
# ### Implementasi Q Learning
# Di sini, kita akan mengimplementasikan algoritma Q Learning. Model Q Learning yang kita buat tentunya dapat digunakan untuk melakukan proses memprediksi performa team ke depannya berdasarkan state sekarang. Dengan membandingkannya dengan nilai Q untuk pilihan yang berbeda, kita bisa melakukan analisis pengaruh win rate dan KDA terhadap performa dari masing-masing team. Model tersebut tentunya bisa memberikan rekomendasi pilihan yang diharapkan mampu untuk meningkatkan performa team.

# %%
team_performance_history = {}
for team, data in team_groups_summary.iterrows():
    state = [int(data['Win rate']), int(data['Avg_KDA'])]
    Q_table = np.zeros((10, 10, 2))  
    team_history = {'Win rate': [state[0]], 'KDA': [state[1]]}
    
    for i in range(episodes):
        action = choose_action(state, epsilon, Q_table)
        next_state = state[:]
        if action == 0:
            next_state[0] = min(next_state[0] + 1, 9)
        else:
            next_state[1] = min(next_state[1] + 1, 9)
        reward = calculate_reward(action, data)
        Q_table[state[0], state[1], action] = Q_table[state[0], state[1], action] + alpha * (
            reward + gamma * np.max(Q_table[next_state[0], next_state[1]]) - Q_table[state[0], state[1], action]
        )
        state = next_state
        team_history['Win rate'].append(state[0])
        team_history['KDA'].append(state[1])
    team_performance_history[team] = team_history

# %% [markdown]
# ### Visualisasi Data
# Di sini, kita akan melakukan proses visualisasi data. Di mana kita akan menghasilkan grafik yang menunjukan bahwasanya perubhana win rate dan KDA dari masing-masing team selema beberapa episode tertentu ternyata mampu untuk meningkatkan performa team. Dengan visualisasi ini juga, kita mampu untuk menganalisis performa antara satu team dengan team lainya untuk mencari team manakah yang memiliki performa terbaik pada Pro Scene League of Legend 2024.

# %%
plt.figure(figsize=(12, 6))
for team, history in team_performance_history.items():
    # Menampilkan Win rate
    plt.subplot(1, 2, 1)
    plt.plot(history['Win rate'], label=f'{team} - Win rate')
    plt.title('Perubahan Win rate selama Episode')
    plt.xlabel('Episode')
    plt.ylabel('Win rate')
    plt.legend(loc='lower right')
    
    # Menampilkan KDA
    plt.subplot(1, 2, 2)
    plt.plot(history['KDA'], label=f'{team} - KDA')
    plt.title('Perubahan KDA selama Episode')
    plt.xlabel('Episode')
    plt.ylabel('KDA')
    plt.legend(loc='lower right')

# Menampilkan semua plot
plt.tight_layout()
plt.show()
